# %%
import os
BASE_DIR = os.environ.get("BASE_DIR", "/mnt/image-net-full/namin/ris")
import pandas as pd

# %%
file_name = 'result_log/per_instance_multilingual_siglip2_refcocog_val_2572_centroid_textlayer_cost.csv'
file_name = 'result_log/per_instance_multilingual_siglip2_refcoco+_testB_1797_centroid_textlayer_cost.csv'
file_name = 'result_log/per_instance_multilingual_siglip2_refcoco_val_3810_centroid_textlayer_cost.csv'

file_name = os.path.join(BASE_DIR, file_name)
df = pd.read_csv(file_name)

print(round(df['visual_elapsed'].mean(), 4))
print(round(df['visual_elapsed'].std(), 4))

print(round(df['text_peak_gpu_mem_MB'].mean(), 4))
print(round(df['text_peak_gpu_mem_MB'].std(), 4))

print()


print(round(df['text_elapsed'].mean(), 4))
print(round(df['text_elapsed'].std(), 4))

print(round(df['visual_peak_gpu_mem_MB'].mean(), 4))
print(round(df['visual_peak_gpu_mem_MB'].std(), 4))
# Out:
# 37.2649
# 13.3891
# 5384.8296
# 385.6874
#
# 0.9132
# 0.3928
# 9955.6562
# 1850.3623

# %%
file_name = 'result_log/per_instance_multilingual_siglip2_refcocog_val_2572_final_textlayer_cost.csv'
file_name = 'result_log/per_instance_multilingual_siglip2_refcoco+_testB_1797_final_textlayer_cost.csv'
file_name = 'result_log/per_instance_multilingual_siglip2_refcoco_val_3810_final_textlayer_cost.csv'

file_name = os.path.join(BASE_DIR, file_name)
df = pd.read_csv(file_name)

print(round(df['visual_elapsed'].mean(), 4))
print(round(df['visual_elapsed'].std(), 4))

print(round(df['text_peak_gpu_mem_MB'].mean(), 4))
print(round(df['text_peak_gpu_mem_MB'].std(), 4))

print()


print(round(df['text_elapsed'].mean(), 4))
print(round(df['text_elapsed'].std(), 4))

print(round(df['visual_peak_gpu_mem_MB'].mean(), 4))
print(round(df['visual_peak_gpu_mem_MB'].std(), 4))
# Out:
# 36.8505
# 12.2169
# 5380.0796
# 385.7126
#
# 0.5874
# 0.2603
# 9951.9173
# 1850.3573

# %%
file_name = 'result_log/per_instance_multilingual_siglip2_refcocog_val_2572_separate_cost.csv'
file_name = 'result_log/per_instance_multilingual_siglip2_refcoco+_testB_1797_separate_cost.csv'
file_name = 'result_log/per_instance_multilingual_siglip2_refcoco_val_3810_separate_cost.csv'

file_name = os.path.join(BASE_DIR, file_name)
df = pd.read_csv(file_name)

print(round(df['visual_elapsed'].mean(), 4))
print(round(df['visual_elapsed'].std(), 4))

print(round(df['text_peak_gpu_mem_MB'].mean(), 4))
print(round(df['text_peak_gpu_mem_MB'].std(), 4))

print()

print(round(df['text_elapsed'].mean(), 4))
print(round(df['text_elapsed'].std(), 4))

print(round(df['visual_peak_gpu_mem_MB'].mean(), 4))
print(round(df['visual_peak_gpu_mem_MB'].std(), 4))
# Out:
# 37.699
# 13.8794
# 5373.4412
# 385.668
#
# 0.575
# 0.2362
# 9947.2147
# 1850.3501
